# %% [markdown]
# <a href="https://colab.research.google.com/github/susmithapremkumar/OIBSIP/blob/main/Car_Price_Prediction_With_MachineLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from IPython.display import Image
Image(url='https://miro.medium.com/v2/resize:fit:1400/1*PD2pzladq6HRqM7_I_j_Rw.png')
# Out:
# <img src="https://miro.medium.com/v2/resize:fit:1400/1*PD2pzladq6HRqM7_I_j_Rw.png"/>

# %%
df = pd.read_csv('/content/carprice.csv')
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19    3.40              10.0        102      5500       24
# 4         mpfi  3.19    3.40               8.0        115      5500       18
#
#    highway-mpg  price
# 0           27  13495
# 1           27  16500
# 2           26  16500
# 3           30  13950
# 4           22  17450
#
# [5 rows x 26 columns]
# Warning: Total number of columns (26) exceeds max_columns (20) limiting to first (20) columns.

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df.shape
# Out:
# (199, 26)

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower             int64
# peak-rpm               int64
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
def value_counts():
    for i in df.columns:
        print(df[i].value_counts())
value_counts()
# Out:
#  0    66
#  1    54
#  2    31
#  3    23
# -1    22
# -2     3
# Name: symboling, dtype: int64
# ?      39
# 161    11
# 91      8
# 134     6
# 128     6
# 104     6
# 85      5
# 94      5
# 65      5
# 102     5
# 74      5
# 168     5
# 103     5
# 95      5
# 148     4
# 93      4
# 106     4
# 118     4
# 122     4
# 83      3
# 150     3
# 154     3
# 125     3
# 115     3
# 101     3
# 137     3
# 158     2
# 145     2
# 87      2
# 89      2
# 197     2
# 81      2
# 119     2
# 113     2
# 194     2
# 108     2
# 129     2
# 188     2
# 110     2
# 164     2
# 153     2
# 192     2
# 90      1
# 256     1
# 78      1
# 121     1
# 77      1
# 98      1
# 186     1
# 142     1
# 107     1
# 231     1
# Name: normalized-losses, dtype: int64
# toyota           32
# nissan           18
# mazda            13
# honda            13
# mitsubishi       13
# subaru           12
# volkswagen       12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# alfa-romero       3
# jaguar            3
# chevrolet         3
# mercury           1
# Name: make, dtype: int64
# gas       179
# diesel     20
# Name: fuel-type, dtype: int64
# std      162
# turbo     37
# Name: aspiration, dtype: int64
# four    113
# two      84
# ?         2
# Name: num-of-doors, dtype: int64
# sedan          96
# hatchback      65
# wagon          24
# hardtop         8
# convertible     6
# Name: body-style, dtype: int64
# fwd    118
# rwd     72
# 4wd      9
# Name: drive-wheels, dtype: int64
# front    196
# rear       3
# Name: engine-location, dtype: int64
# 94.5     21
# 93.7     20
# 95.7     13
# 96.5      8
# 97.3      7
# 98.4      7
# 104.3     6
# 100.4     6
# 107.9     6
# 98.8      6
# 99.1      6
# 96.3      6
# 93.1      5
# 109.1     5
# 95.9      5
# 102.4     5
# 97.2      5
# 97.0      4
# 114.2     4
# 101.2     4
# 110.0     3
# 103.5     3
# 89.5      3
# 105.8     3
# 96.9      2
# 102.9     2
# 91.3      2
# 104.5     2
# 88.6      2
# 113.0     2
# 99.8      2
# 115.6     2
# 103.3     2
# 86.6      2
# 104.9     2
# 93.3      1
# 99.4      1
# 99.5      1
# 88.4      1
# 94.3      1
# 96.0      1
# 93.0      1
# 95.1      1
# 102.0     1
# 108.0     1
# 106.7     1
# 99.2      1
# 96.6      1
# 112.0     1
# 102.7     1
# 120.9     1
# Name: wheel-base, dtype: int64
# 157.3    15
# 188.8    11
# 171.7     7
# 186.7     7
# 166.3     7
#          ..
# 165.6     1
# 187.5     1
# 180.3     1
# 208.1     1
# 199.2     1
# Name: length, Length: 73, dtype: int64
# 63.8    24
# 66.5    22
# 65.4    15
# 63.6    11
# 68.4    10
# 64.4    10
# 64.0     9
# 65.5     8
# 65.2     7
# 66.3     6
# 64.2     6
# 67.2     6
# 65.6     6
# 67.9     5
# 66.9     5
# 68.9     4
# 64.8     4
# 71.4     3
# 63.9     3
# 71.7     3
# 65.0     3
# 70.3     3
# 68.3     2
# 66.1     2
# 64.1     2
# 69.6     2
# 64.6     2
# 67.7     2
# 63.4     1
# 72.3     1
# 70.6     1
# 68.0     1
# 72.0     1
# 70.5     1
# 61.8     1
# 66.0     1
# 62.5     1
# 60.3     1
# 70.9     1
# 66.4     1
# 66.2     1
# 68.8     1
# Name: width, dtype: int64
# 50.8    14
# 55.7    12
# 52.0    12
# 54.1    10
# 54.5    10
# 55.5     9
# 54.3     8
# 56.7     8
# 52.6     7
# 51.6     7
# 56.1     7
# 50.2     6
# 52.8     6
# 54.9     6
# 53.0     6
# 50.6     5
# 55.1     5
# 53.7     5
# 53.3     4
# 58.7     4
# 52.5     3
# 49.7     3
# 59.1     3
# 53.5     3
# 56.2     3
# 57.5     3
# 54.7     2
# 53.9     2
# 49.4     2
# 48.8     2
# 59.8     2
# 56.5     2
# 54.4     2
# 51.4     2
# 56.3     2
# 55.4     1
# 53.1     1
# 55.6     1
# 55.9     1
# 53.2     1
# 56.0     1
# 50.5     1
# 54.8     1
# 58.3     1
# 51.0     1
# 52.4     1
# 47.8     1
# Name: height, dtype: int64
# 2385    3
# 1918    3
# 1989    3
# 2275    3
# 2756    2
#        ..
# 2370    1
# 2328    1
# 2833    1
# 2921    1
# 3062    1
# Name: curb-weight, Length: 168, dtype: int64
# ohc      146
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# dohcv      1
# Name: engine-type, dtype: int64
# four      157
# six        24
# five       11
# eight       5
# three       1
# twelve      1
# Name: num-of-cylinders, dtype: int64
# 122    15
# 92     15
# 97     14
# 98     14
# 108    13
# 90     12
# 110    12
# 109     8
# 120     7
# 141     7
# 146     6
# 121     6
# 181     6
# 152     6
# 91      5
# 156     5
# 136     5
# 183     4
# 130     4
# 194     3
# 171     3
# 164     3
# 209     3
# 140     2
# 134     2
# 234     2
# 131     2
# 258     2
# 326     1
# 173     1
# 161     1
# 203     1
# 61      1
# 151     1
# 79      1
# 103     1
# 111     1
# 304     1
# 308     1
# 119     1
# 145     1
# Name: engine-size, dtype: int64
# mpfi    91
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# mfi      1
# spfi     1
# Name: fuel-system, dtype: int64
# 3.62    23
# 3.19    20
# 3.15    15
# 3.03    12
# 2.97    12
# 3.78     8
# 3.31     8
# 3.43     8
# 3.46     7
# 3.27     7
# 2.91     7
# 3.54     6
# 3.05     6
# 3.58     6
# 3.39     6
# 3.01     5
# 3.70     5
# 3.35     4
# 3.17     3
# 3.59     3
# 3.74     3
# 3.33     2
# 3.24     2
# 3.94     2
# 3.47     2
# 3.80     2
# 3.63     2
# 3.50     2
# 3.13     2
# 2.68     1
# 2.99     1
# 3.08     1
# 3.61     1
# 2.92     1
# 3.60     1
# 2.54     1
# 3.34     1
# 3.76     1
# Name: bore, dtype: int64
# 3.40    20
# 3.15    14
# 3.03    14
# 3.23    14
# 3.39    13
# 2.64    11
# 3.29     9
# 3.35     9
# 3.46     8
# 3.27     6
# 3.58     6
# 3.07     6
# 3.41     6
# 3.50     6
# 3.11     6
# 3.19     6
# 3.52     5
# 3.64     5
# 3.47     4
# 3.54     4
# 3.86     4
# 2.90     3
# 3.08     2
# 2.19     2
# 2.68     2
# 3.10     2
# 4.17     2
# 2.80     2
# 3.12     1
# 3.21     1
# 3.16     1
# 2.07     1
# 2.36     1
# 2.76     1
# 3.90     1
# 2.87     1
# Name: stroke, dtype: int64
# 9.00     46
# 9.40     22
# 8.50     14
# 9.50     13
# 9.30     11
# 8.00      8
# 9.20      8
# 8.70      7
# 7.00      7
# 8.60      5
# 21.00     5
# 8.40      5
# 7.50      5
# 23.00     5
# 9.60      5
# 21.50     4
# 7.60      4
# 10.00     3
# 22.50     3
# 8.30      3
# 8.80      3
# 7.70      2
# 8.10      2
# 9.10      1
# 9.31      1
# 7.80      1
# 9.41      1
# 21.90     1
# 22.00     1
# 22.70     1
# 10.10     1
# 11.50     1
# Name: compression-ratio, dtype: int64
# 68     19
# 70     11
# 69     10
# 116     9
# 110     8
# 95      7
# 88      6
# 62      6
# 160     6
# 114     6
# 84      5
# 102     5
# 145     5
# 76      5
# 97      5
# 82      5
# 123     4
# 86      4
# 92      4
# 111     4
# 207     3
# 73      3
# 152     3
# 90      3
# 85      3
# 182     3
# 121     3
# 101     3
# 56      2
# 112     2
# 94      2
# 161     2
# 52      2
# 162     2
# 156     2
# 155     2
# 176     2
# 184     2
# 100     2
# 55      1
# 134     1
# 115     1
# 140     1
# 48      1
# 58      1
# 60      1
# 78      1
# 262     1
# 200     1
# 64      1
# 120     1
# 72      1
# 154     1
# 288     1
# 143     1
# 142     1
# 175     1
# 106     1
# Name: horsepower, dtype: int64
# 5500    37
# 4800    36
# 5000    27
# 5200    23
# 5400    13
# 5800     7
# 5250     7
# 4500     7
# 4150     5
# 6000     5
# 4200     5
# 4350     4
# 4750     4
# 5100     3
# 5900     3
# 4250     3
# 4400     3
# 6600     2
# 4650     1
# 5600     1
# 5750     1
# 4900     1
# 5300     1
# Name: peak-rpm, dtype: int64
# 31    28
# 19    27
# 24    22
# 27    14
# 26    12
# 17    10
# 23    10
# 21     8
# 25     8
# 30     8
# 38     7
# 28     7
# 37     6
# 16     5
# 22     4
# 29     3
# 15     3
# 20     3
# 18     3
# 14     2
# 34     1
# 35     1
# 32     1
# 36     1
# 45     1
# 13     1
# 49     1
# 47     1
# 33     1
# Name: city-mpg, dtype: int64
# 25    19
# 24    17
# 38    17
# 30    16
# 32    16
# 34    14
# 37    13
# 28    13
# 29    10
# 33     9
# 22     8
# 31     6
# 27     5
# 43     4
# 26     3
# 41     3
# 23     3
# 42     3
# 39     2
# 16     2
# 47     2
# 36     2
# 20     2
# 46     2
# 18     2
# 19     2
# 50     1
# 53     1
# 17     1
# 54     1
# Name: highway-mpg, dtype: int64
# ?        4
# 5572     2
# 7957     2
# 8495     2
# 7295     2
#         ..
# 5389     1
# 6189     1
# 6669     1
# 7689     1
# 22625    1
# Name: price, Length: 181, dtype: int64

# %%
df.shape
# Out:
# (199, 26)

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df.drop(columns=['symboling'],axis=1,inplace=True)

# %%
df
# Out:
#     normalized-losses         make fuel-type aspiration num-of-doors  \
# 0                   ?  alfa-romero       gas        std          two
# 1                   ?  alfa-romero       gas        std          two
# 2                   ?  alfa-romero       gas        std          two
# 3                 164         audi       gas        std         four
# 4                 164         audi       gas        std         four
# ..                ...          ...       ...        ...          ...
# 194                95        volvo       gas        std         four
# 195                95        volvo       gas      turbo         four
# 196                95        volvo       gas        std         four
# 197                95        volvo    diesel      turbo         four
# 198                95        volvo       gas      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base  length  ...  \
# 0    convertible          rwd           front        88.6   168.8  ...
# 1    convertible          rwd           front        88.6   168.8  ...
# 2      hatchback          rwd           front        94.5   171.2  ...
# 3          sedan          fwd           front        99.8   176.6  ...
# 4          sedan          4wd           front        99.4   176.6  ...
# ..           ...          ...             ...         ...     ...  ...
# 194        sedan          rwd           front       109.1   188.8  ...
# 195        sedan          rwd           front       109.1   188.8  ...
# 196        sedan          rwd           front       109.1   188.8  ...
# 197        sedan          rwd           front       109.1   188.8  ...
# 198        sedan          rwd           front       109.1   188.8  ...
#
#      engine-size  fuel-system  bore stroke compression-ratio  horsepower  \
# 0            130         mpfi  3.47   2.68               9.0         111
# 1            130         mpfi  3.47   2.68               9.0         111
# 2            152         mpfi  2.68   3.47               9.0         154
# 3            109         mpfi  3.19   3.40              10.0         102
# 4            136         mpfi  3.19   3.40               8.0         115
# ..           ...          ...   ...    ...               ...         ...
# 194          141         mpfi  3.78   3.15               9.5         114
# 195          141         mpfi  3.78   3.15               8.7         160
# 196          173         mpfi  3.58   2.87               8.8         134
# 197          145          idi  3.01   3.40              23.0         106
# 198          141         mpfi  3.78   3.15               9.5         114
#
#     peak-rpm  city-mpg  highway-mpg  price
# 0       5000        21           27  13495
# 1       5000        21           27  16500
# 2       5000        19           26  16500
# 3       5500        24           30  13950
# 4       5500        18           22  17450
# ..       ...       ...          ...    ...
# 194     5400        23           28  16845
# 195     5300        19           25  19045
# 196     5500        18           23  21485
# 197     4800        26           27  22470
# 198     5400        19           25  22625
#
# [199 rows x 25 columns]
# Warning: Total number of columns (25) exceeds max_columns (20) limiting to first (20) columns.

# %%
df.columns
# Out:
# Index(['normalized-losses', 'make', 'fuel-type', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price'],
#       dtype='object')

# %%
numerical_feat =[]
categorical_feat=[]
for i in df.columns:
    if (df[i].dtypes !=object):
        numerical_feat.append(i)
    else:
        categorical_feat.append(i)

# %%
df.dtypes
# Out:
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower             int64
# peak-rpm               int64
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
numerical_feat
# Out:
# ['wheel-base',
#  'length',
#  'width',
#  'height',
#  'curb-weight',
#  'engine-size',
#  'bore',
#  'stroke',
#  'compression-ratio',
#  'horsepower',
#  'peak-rpm',
#  'city-mpg',
#  'highway-mpg']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
len(categorical_feat)
# Out:
# 12

# %%
categorical_feat
# Out:
# ['normalized-losses',
#  'make',
#  'fuel-type',
#  'aspiration',
#  'num-of-doors',
#  'body-style',
#  'drive-wheels',
#  'engine-location',
#  'engine-type',
#  'num-of-cylinders',
#  'fuel-system',
#  'price']

# %%
numerical_feat
# Out:
# ['wheel-base',
#  'length',
#  'width',
#  'height',
#  'curb-weight',
#  'engine-size',
#  'bore',
#  'stroke',
#  'compression-ratio',
#  'horsepower',
#  'peak-rpm',
#  'city-mpg',
#  'highway-mpg']

# %%
len(numerical_feat)
# Out:
# 13

# %%
df.corr()
# Out:
# <ipython-input-23-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    wheel-base    length     width    height  curb-weight  \
# wheel-base           1.000000  0.877830  0.799241  0.591087     0.776964
# length               0.877830  1.000000  0.841872  0.495293     0.878730
# width                0.799241  0.841872  1.000000  0.287340     0.868035
# height               0.591087  0.495293  0.287340  1.000000     0.295271
# curb-weight          0.776964  0.878730  0.868035  0.295271     1.000000
# engine-size          0.567018  0.685996  0.745969  0.024678     0.858950
# bore                 0.493610  0.606845  0.558674  0.179330     0.650206
# stroke               0.174585  0.124223  0.180802 -0.050127     0.174149
# compression-ratio    0.247314  0.158942  0.182130  0.262772     0.150350
# horsepower           0.355572  0.557854  0.643778 -0.109577     0.752863
# peak-rpm            -0.353042 -0.282565 -0.224201 -0.277248    -0.265418
# city-mpg            -0.497791 -0.694087 -0.656039 -0.098838    -0.779190
# highway-mpg         -0.566580 -0.725085 -0.688582 -0.152418    -0.814852
#
#                    engine-size      bore    stroke  compression-ratio  \
# wheel-base            0.567018  0.493610  0.174585           0.247314
# length                0.685996  0.606845  0.124223           0.158942
# width                 0.745969  0.558674  0.180802           0.182130
# height                0.024678  0.179330 -0.050127           0.262772
# curb-weight           0.858950  0.650206  0.174149           0.150350
# engine-size           1.000000  0.594333  0.209111           0.024894
# bore                  0.594333  1.000000 -0.067193           0.006963
# stroke                0.209111 -0.067193  1.000000           0.197955
# compression-ratio     0.024894  0.006963  0.197955           1.000000
# horsepower            0.829072  0.577273  0.090254          -0.205759
# peak-rpm             -0.207293 -0.264269 -0.071493          -0.444595
# city-mpg             -0.711683 -0.593901 -0.036136           0.324577
# highway-mpg          -0.728680 -0.595321 -0.045779           0.264684
#
#                    horsepower  peak-rpm  city-mpg  highway-mpg
# wheel-base           0.355572 -0.353042 -0.497791    -0.566580
# length               0.557854 -0.282565 -0.694087    -0.725085
# width                0.643778 -0.224201 -0.656039    -0.688582
# height              -0.109577 -0.277248 -0.098838    -0.152418
# curb-weight          0.752863 -0.265418 -0.779190    -0.814852
# engine-size          0.829072 -0.207293 -0.711683    -0.728680
# bore                 0.577273 -0.264269 -0.593901    -0.595321
# stroke               0.090254 -0.071493 -0.036136    -0.045779
# compression-ratio   -0.205759 -0.444595  0.324577     0.264684
# horsepower           1.000000  0.130772 -0.814819    -0.779032
# peak-rpm             0.130772  1.000000 -0.069687    -0.013620
# city-mpg            -0.814819 -0.069687  1.000000     0.971530
# highway-mpg         -0.779032 -0.013620  0.971530     1.000000

# %%
plt.figure(figsize = (16,5))
ax = sns.heatmap(df.corr(), annot=True, linewidths=.1)
# Out:
# <ipython-input-24-35ff1cf5cfc2>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ax = sns.heatmap(df.corr(), annot=True, linewidths=.1)

# %%
df[categorical_feat].head()
# Out:
#   normalized-losses         make fuel-type aspiration num-of-doors  \
# 0                 ?  alfa-romero       gas        std          two
# 1                 ?  alfa-romero       gas        std          two
# 2                 ?  alfa-romero       gas        std          two
# 3               164         audi       gas        std         four
# 4               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location engine-type num-of-cylinders  \
# 0  convertible          rwd           front        dohc             four
# 1  convertible          rwd           front        dohc             four
# 2    hatchback          rwd           front        ohcv              six
# 3        sedan          fwd           front         ohc             four
# 4        sedan          4wd           front         ohc             five
#
#   fuel-system  price
# 0        mpfi  13495
# 1        mpfi  16500
# 2        mpfi  16500
# 3        mpfi  13950
# 4        mpfi  17450

# %%
discrete_feature=[feature for feature in numerical_feat if len(df[feature].unique())<25 and feature not in ['Id']]
print("Discrete Variables Count: {}".format(len(discrete_feature)))
# Out:
# Discrete Variables Count: 1

# %%
discrete_feature
# Out:
# ['peak-rpm']

# %%
df[discrete_feature].head()
# Out:
#    peak-rpm
# 0      5000
# 1      5000
# 2      5000
# 3      5500
# 4      5500

# %%
x=df[numerical_feat]
x
# Out:
#      wheel-base  length  width  height  curb-weight  engine-size  bore  \
# 0          88.6   168.8   64.1    48.8         2548          130  3.47
# 1          88.6   168.8   64.1    48.8         2548          130  3.47
# 2          94.5   171.2   65.5    52.4         2823          152  2.68
# 3          99.8   176.6   66.2    54.3         2337          109  3.19
# 4          99.4   176.6   66.4    54.3         2824          136  3.19
# ..          ...     ...    ...     ...          ...          ...   ...
# 194       109.1   188.8   68.9    55.5         2952          141  3.78
# 195       109.1   188.8   68.8    55.5         3049          141  3.78
# 196       109.1   188.8   68.9    55.5         3012          173  3.58
# 197       109.1   188.8   68.9    55.5         3217          145  3.01
# 198       109.1   188.8   68.9    55.5         3062          141  3.78
#
#      stroke  compression-ratio  horsepower  peak-rpm  city-mpg  highway-mpg
# 0      2.68                9.0         111      5000        21           27
# 1      2.68                9.0         111      5000        21           27
# 2      3.47                9.0         154      5000        19           26
# 3      3.40               10.0         102      5500        24           30
# 4      3.40                8.0         115      5500        18           22
# ..      ...                ...         ...       ...       ...          ...
# 194    3.15                9.5         114      5400        23           28
# 195    3.15                8.7         160      5300        19           25
# 196    2.87                8.8         134      5500        18           23
# 197    3.40               23.0         106      4800        26           27
# 198    3.15                9.5         114      5400        19           25
#
# [199 rows x 13 columns]

# %%
y = df.iloc[:,-1:]
y
# Out:
#      price
# 0    13495
# 1    16500
# 2    16500
# 3    13950
# 4    17450
# ..     ...
# 194  16845
# 195  19045
# 196  21485
# 197  22470
# 198  22625
#
# [199 rows x 1 columns]

# %%
from sklearn.decomposition import PCA
feat = PCA(n_components=5)
feat
# Out:
# PCA(n_components=5)

# %%
feat.fit(x)
# Out:
# PCA(n_components=5)

# %%
feat.components_
# Out:
# array([[ 8.22837473e-03,  1.79830242e-02,  3.00472797e-03,
#          1.48995733e-03,  8.42716854e-01,  5.63882564e-02,
#          3.04647238e-04,  9.27587804e-05,  2.21826882e-03,
#          3.80141166e-02, -5.33564282e-01, -6.72681529e-03,
#         -7.75478593e-03],
#        [ 2.72942923e-03,  9.61139691e-03,  1.92424541e-03,
#         -3.66331617e-04,  5.29491273e-01,  3.78870849e-02,
#          1.23446350e-04,  3.68529260e-05, -3.04288428e-03,
#          6.00105748e-02,  8.45175390e-01, -9.13633506e-03,
#         -9.18901551e-03],
#        [-6.55010488e-02, -7.73408730e-02, -1.71136297e-03,
#         -4.42478848e-02, -9.09558927e-02,  6.61679328e-01,
#          1.60815288e-03,  2.61636883e-04, -4.18170524e-02,
#          7.32706061e-01, -2.45260653e-02, -4.09844964e-02,
#         -2.79989390e-02],
#        [ 6.05025571e-02,  1.71359322e-02,  4.77605975e-03,
#          2.08946707e-03, -7.70465621e-03,  7.43510491e-01,
#         -3.07512649e-03,  4.64015864e-03,  4.54197458e-02,
#         -6.54130710e-01,  1.94169516e-02,  9.18517729e-02,
#          6.60054457e-02],
#        [-3.24796896e-01, -8.19097400e-01, -5.32414823e-02,
#         -1.26402213e-01,  3.17132863e-02, -5.41789942e-02,
#         -6.87605420e-03,  5.18640155e-03,  2.07696806e-01,
#         -3.20592659e-02,  2.08225491e-03,  2.82674483e-01,
#          2.76918790e-01]])

# %%
feat.get_feature_names_out()
# Out:
# array(['pca0', 'pca1', 'pca2', 'pca3', 'pca4'], dtype=object)

# %%
feat.get_params()
# Out:
# {'copy': True,
#  'iterated_power': 'auto',
#  'n_components': 5,
#  'n_oversamples': 10,
#  'power_iteration_normalizer': 'auto',
#  'random_state': None,
#  'svd_solver': 'auto',
#  'tol': 0.0,
#  'whiten': False}
